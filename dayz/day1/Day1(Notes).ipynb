# %% [markdown]
# ## Python Basics

# %% [markdown]
# **Data Types**

# %% [markdown]
# There are only 4 basic data types in py
#
# - int
# - float
# - str
# - boolean

# %% [markdown]
# **Operations**

# %% [markdown]
# - \= : Assignment operator
# - \+ : Addition
# - \- : Subtraction
# - \/ : Divide
# - \// : Integer Division
# - \* : Multiply
# - \% : Modulo

# %% [markdown]
# **PEMDAS**
#
# **P**arentheses
# **E**xponentiation
# **M**ultiplcation
# **D**vision
# **A**ddition
# **S**ubtraction
