# %% [markdown]
# ## Python Basics

# %% [markdown]
# **Data Types**

# %% [markdown]
# There are only 4 basic data types in py
#
# - int
# - float
# - str
# - boolean

# %% [markdown]
# **Operations**

# %% [markdown]
# - \= : Assignment operator
# - \+ : Addition
# - \- :
