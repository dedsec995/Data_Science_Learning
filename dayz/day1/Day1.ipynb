# %% [markdown]
# # Training Starts Today!!

# %% [raw]
# Yep, Pretty Much

# %%
print("Done Piece")
# Out:
# Done Piece

# %%
x = 9999

# %%
type(x)
# Out:
# int

# %%
x = "A"

# %%
type(x)
# Out:
# str

# %%
x = 8
y = 3.5
print(f"x + y = {x+y}")
print(f"x - y = {x-y}")
print(f"x * y = {x*y}")
print(f"x / y = {x/y}")
print(f"x // y = {x//y}")
# Out:
# x + y = 11.5
# x - y = 4.5
# x * y = 28.0
# x / y = 2.2857142857142856
# x // y = 2.0

# %%
the_input = input("Please enter your bank account no.")
# Out:
# Please enter your bank account no. 123456790

# %%
print(the_input)
# Out:
# 123456790

# %%
print(type(the_input))
typecast_input = int(the_input)
print(type(typecast_input))
# Out:
# <class 'str'>
# <class 'int'>

# %%
varA = float(input("Enter the first var: "))
varB = float(input("Enter the Second var: "))
op = input("Enter the operator: ")
print()
print()
print()
print("The Result.....")
if(op == '+'):
    print(f"{varA} {op} {varB} = {varA+varB}")
elif(op == '-'):
    print(f"{varA} {op} {varB} = {varA-varB}")
elif(op == '*'):
    print(f"{varA} {op} {varB} = {varA*varB}")
elif(op == '/'):
    print(f"{varA} {op} {varB} = {varA//varB}")
else:
    print("Please enter correct input's again")
# Out:
# Enter the first var:  5
# Enter the Second var:  4
# Enter the operator:  +
# The Result.....
# 5.0 + 4.0 = 9.0

# %%
while True:
    print("YaY")

# %%
cont = 'y'

while cont == 'y':
    varA = float(input("Enter the first var: "))
    varB = float(input("Enter the Second var: "))
    op = input("Enter the operator: ")
    print()
    print()
    print()
    print()
    if(op == '+'):
        print(f"{varA} {op} {varB} = {varA+varB}")
    elif(op == '-'):
        print(f"{varA} {op} {varB} = {varA-varB}")
    elif(op == '*'):
        print(f"{varA} {op} {varB} = {varA*varB}")
    elif(op == '/'):
        print(f"{varA} {op} {varB} = {varA//varB}")
    else:
        print("Please enter correct input's again")
    cont = input("Do you want to continue(y/n)?")
    print()
    print()
    print()
    print()
print("### --- Good Bye Dream Boat --- ###")
# Out:
# Enter the first var:  3
# Enter the Second var:  5
# Enter the operator:  +
# 3.0 + 5.0 = 8.0
# Do you want to continue(y/n)? y
# Enter the first var:  2
# Enter the Second var:  4
# Enter the operator:  -
# 2.0 - 4.0 = -2.0
# Do you want to continue(y/n)? 2
# ### --- Good Bye Dream Boat --- ###

# %%
def addme(a,b):
    return a+b

def subme(a,b):
    return a-b

def mulme(a,b):
    return a*b

def divme(a,b):
    if b == 0:
        return -2**31
    return a/b

def andme():
    varA = int(input("Enter the first var(1/0): "))
    varB = int(input("Enter the second var(1/0): "))
    if(varA == 1 or varA == 0) and (varB == 0 or varB == 1):
        if(varA == 1):
            varA = True
        else:
            varA = False
        if(varB == 1):
            varB = True
        else:
            varB = False
        print(f"{varA} and {varB} = {(varA or varB)}")
    else:
        print("Wrong input, go again")
        
def notme():
    varA = int(input("Enter the first var(1/0): "))
    if(varA == 1 or varA == 0):
        if(varA == 1):
            varA = True
        else:
            varA = False
        print(f"{varA} not = {(not varA)}")
    else:
        print("Wrong input, go again")

def orme():
    varA = int(input("Enter the first var(1/0): "))
    varB = int(input("Enter the second var(1/0): "))
    if(varA == 1 or varA == 0) and (varB == 0 or varB == 1):
        if(varA == 1):
            varA = True
        else:
            varA = False
        if(varB == 1):
            varB = True
        else:
            varB = False
        print(f"{varA} or {varB} = {(varA or varB)}")
    else:
        print("Wrong input, go again")

def mathulator():
    varA = float(input("Enter the first var: "))
    varB = float(input("Enter the Second var: "))
    op = input("Enter the operator(add,sub,mul,div): ")
    if(op == 'add'):
        print(f"{varA} + {varB} = {addme(varA,varB)}")
    elif(op == 'sub'):
        print(f"{varA} - {varB} = {subme(varA,varB)}")
    elif(op == 'mul'):
        print(f"{varA} * {varB} = {mulme(varA,varB)}")
    elif(op == 'div'):
        rez = divme(varA,varB)
        if(rez == -2**31):
            print(f"Cannot Divide by zero")
        else:
            print(f"{varA} / {varB} = {divme(varA,varB)}")
    else:
        print("Please enter correct input's")
    cont = input("Do you want to continue(y/n)?")
    print()
    print()
    print()
    print()
    return cont

def logulator():
    op = input("Enter the operator(and,or,not): ")
    if(op == 'and'):
        andme()
    elif(op == 'or'):
        orme()    
    elif(op == 'not'):
        notme()    
    else:
        print("Please select the correct operator's")    
    cont = input("Do you want to continue(y/n)?")
    print()
    print()
    print()
    print()
    return cont
    
cont = 'y'

while cont == 'y':
    print("1. Mathematical Operations")
    print("2. Logical Operatoins")
    ulator = input("Which one do you want!!")
    
    if(ulator == '1'):
        cont = mathulator()
    elif (ulator == '2'):
        cont = logulator()
    else:
        print("Enter either 1 or 2")
    
print("### --- Good Bye Dream Boat --- ###")
# Out:
# 1. Mathematical Operations
# 2. Logical Operatoins
# Which one do you want!! 2
# Enter the operator(and,or,not):  or
# Enter the first var(1/0):  2
# Enter the second var(1/0):  3
# Wrong input, go again
# Do you want to continue(y/n)? y
# 1. Mathematical Operations
# 2. Logical Operatoins
# Which one do you want!! 2
# Enter the operator(and,or,not):  or
# Enter the first var(1/0):  1
# Enter the second var(1/0):  0
# True or False = True
# Do you want to continue(y/n)? y
# 1. Mathematical Operations
# 2. Logical Operatoins
# Which one do you want!! 1
# Enter the first var:  4
# Enter the Second var:  5
# Enter the operator(add,sub,mul,div):  div
# 4.0 / 5.0 = 0.8
